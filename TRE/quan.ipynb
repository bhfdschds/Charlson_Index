# %% [markdown]
# # Quan map experiment

# %%
import pandas as pd

# %%
quan_csv = pd.read_csv("quan_codelist.csv", index_col=False, dtype=str)

# %%
quan_csv.columns
# Out:
# Index(['name', ' terminology', ' code', ' description', ' code_type',
#        ' RecordDate'],
#       dtype='object')

# %%
[tuple(x) for x in quan_csv.to_records(index=False)]
# Out:
# [('mi', 'ICD10', 'I21', 'I21 Acute myocardial infarction', '1', '20221212'),
#  ('mi',
#   'ICD10',
#   'I22',
#   'I22 Subsequent myocardial infarction',
#   '1',
#   '20221212'),
#  ('mi', 'ICD10', 'I252', 'I25.2 Old myocardial infarction', '0', '20221212'),
#  ('chf',
#   'ICD10',
#   'I099',
#   'I09.9 Rheumatic heart disease, unspecified',
#   '1',
#   '20221212'),
#  ('chf',
#   'ICD10',
#   'I110',
#   'I11.0 Hypertensive heart disease with (congestive) heart failure',
#   '1',
#   '20221212'),
#  ('chf',
#   'ICD10',
#   'I130',
#   'I13.0 Hypertensive heart and renal disease with (congestive) heart failure',
#   '1',
#   '20221212'),
#  ('chf',
#   'ICD10',
#   'I132',
#   'I13.2 Hypertensive heart and renal disease with both (congestive) heart failure and renal failure',
#   '1',
#   '20221212'),
#  ('chf', 'ICD10', 'I255', 'I25.5 Ischaemic cardiomyopathy', '1', '20221212'),
#  ('chf', 'ICD10', 'I420', 'I42.0 Dilated cardiomyopathy', '1', '20221212'),
#  ('chf',
# ...

# %%
a, *rest = [1,2,3]
print(a)
print(rest)
# Out:
# 1
# [2, 3]

# %%
a, *rest, c = [1,2,3,5,6,7]
print(a)
print(rest)
print(c)
# Out:
# 1
# [2, 3, 5, 6]
# 7
